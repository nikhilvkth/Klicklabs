# %%
import pandas as pd

man_whi = pd.read_csv('/Users/nvalsankulangareth/MannWhitney/output_V2H_merged.csv')
mw_df = pd.DataFrame(man_whi)
mw_df
#mw_df_listcheck = mw_df.iloc[:,-1]
#mw_df_listcheck.to_excel("listcheck.xlsx")
# Out:
#                  sample_name  audspec_lengthL1norm_sma_range_IC13  \
# 0        1MH004F8NH4_Sample2                             3.941891
# 1        1MH004F8NH4_Sample3                             3.382757
# 2        1MH004F8NH4_Sample4                             2.943043
# 3        1MH004F8NH4_Sample5                             3.452679
# 4        1MH004F8NH4_Sample6                             3.477017
# ...                      ...                                  ...
# 36323  1MH007405DW_Sample100                             2.245195
# 36324  1MH007405DW_Sample101                             2.355750
# 36325  1MH007405DW_Sample102                             2.045330
# 36326  1MH007405DW_Sample103                             0.714013
# 36327  1MH007405DW_Sample104                             1.174387
#
#        audspec_lengthL1norm_sma_maxPos_IC13  \
# 0                                  0.187654
# 1                                  0.037143
# ...

# %%
#print(mw_df.columns)
print(mw_df.outcome.value_counts())
# Out:
# N    22427
# X    10262
# Y     3639
# Name: outcome, dtype: int64

# %%
mw_df_sample = mw_df.iloc[:,1:]
mw_df_sample
# Out:
#        audspec_lengthL1norm_sma_range_IC13  \
# 0                                 3.941891
# 1                                 3.382757
# 2                                 2.943043
# 3                                 3.452679
# 4                                 3.477017
# ...                                    ...
# 36323                             2.245195
# 36324                             2.355750
# 36325                             2.045330
# 36326                             0.714013
# 36327                             1.174387
#
#        audspec_lengthL1norm_sma_maxPos_IC13  \
# 0                                  0.187654
# 1                                  0.037143
# 2                                  0.196560
# 3                                  0.410569
# 4                                  0.274559
# ...                                     ...
# 36323                              0.904000
# 36324                              0.987433
# ...

# %%
#print(mw_df_sample.columns)
mw_df_sample_1 = mw_df_sample.loc[mw_df_sample['outcome']== 'N']
mw_df_sample_1
# Out:
#        audspec_lengthL1norm_sma_range_IC13  \
# 0                                 3.941891
# 1                                 3.382757
# 2                                 2.943043
# 3                                 3.452679
# 4                                 3.477017
# ...                                    ...
# 36323                             2.245195
# 36324                             2.355750
# 36325                             2.045330
# 36326                             0.714013
# 36327                             1.174387
#
#        audspec_lengthL1norm_sma_maxPos_IC13  \
# 0                                  0.187654
# 1                                  0.037143
# 2                                  0.196560
# 3                                  0.410569
# 4                                  0.274559
# ...                                     ...
# 36323                              0.904000
# 36324                              0.987433
# ...

# %%
mw_df_sample_2 = mw_df_sample.loc[mw_df_sample['outcome']== 'Y']
mw_df_sample_2
# Out:
#        audspec_lengthL1norm_sma_range_IC13  \
# 526                               4.039576
# 527                               3.675001
# 528                               3.048258
# 529                               5.633812
# 530                               4.828854
# ...                                    ...
# 35194                             1.986241
# 35195                             1.237639
# 35196                             1.048987
# 35197                             1.287170
# 35198                             1.597007
#
#        audspec_lengthL1norm_sma_maxPos_IC13  \
# 526                                0.030660
# 527                                0.251323
# 528                                0.872114
# 529                                0.035443
# 530                                0.032020
# ...                                     ...
# 35194                              0.117517
# 35195                              0.227027
# ...

# %%
mw_df_sample_X = mw_df_sample.loc[mw_df_sample['outcome']== 'X']
mw_df_sample_X
# Out:
#        audspec_lengthL1norm_sma_range_IC13  \
# 302                               1.492574
# 303                               0.896060
# 304                               1.748953
# 305                               2.041833
# 306                               1.092066
# ...                                    ...
# 36010                             2.181401
# 36011                             2.177090
# 36012                             2.615895
# 36013                             2.485622
# 36014                             1.903921
#
#        audspec_lengthL1norm_sma_maxPos_IC13  \
# 302                                0.046931
# 303                                0.913534
# 304                                0.201754
# 305                                0.206897
# 306                                0.729222
# ...                                     ...
# 36010                              0.083832
# 36011                              0.397004
# ...

# %%
mw_df_sample_dupli = mw_df_sample.pivot_table(index = ['outcome'], aggfunc ='size')
mw_df_sample_dupli
# Out:
# outcome
# N    22427
# X    10262
# Y     3639
# dtype: int64

# %%
mw_df_sample_1.iloc[:,0]
# Out:
# 0        3.941891
# 1        3.382757
# 2        2.943043
# 3        3.452679
# 4        3.477017
#            ...
# 36323    2.245195
# 36324    2.355750
# 36325    2.045330
# 36326    0.714013
# 36327    1.174387
# Name: audspec_lengthL1norm_sma_range_IC13, Length: 22427, dtype: float64

# %%
mw_df_sample_2.iloc[:,0]
# Out:
# 526      4.039576
# 527      3.675001
# 528      3.048258
# 529      5.633812
# 530      4.828854
#            ...
# 35194    1.986241
# 35195    1.237639
# 35196    1.048987
# 35197    1.287170
# 35198    1.597007
# Name: audspec_lengthL1norm_sma_range_IC13, Length: 3639, dtype: float64

# %%
from scipy.stats import mannwhitneyu
list =[]


for i in range(0,len(mw_df_sample_1.columns)-1):
    test_a = pd.DataFrame(mw_df_sample_1.iloc[:,i])
    test_b = pd.DataFrame(mw_df_sample_2.iloc[:,i])
    list.append((mannwhitneyu(mw_df_sample_1.iloc[:,i], mw_df_sample_2.iloc[:,i])))
list_MWP = pd.DataFrame(list)
list_MWP
# Out:
#        statistic        pvalue
# 0     41693794.0  3.496982e-02
# 1     41931322.5  7.521115e-03
# 2     41908909.5  8.494348e-03
# 3     46341361.5  1.772744e-39
# 4     43481850.5  2.078985e-10
# ...          ...           ...
# 6363  39587682.0  3.811417e-03
# 6364  44241712.0  3.348007e-16
# 6365  41672192.0  3.964753e-02
# 6366  44253763.5  2.640554e-16
# 6367  42136336.0  1.579009e-03
#
# [6368 rows x 2 columns]

# %%
feature = (mw_df_sample.columns)
#print(feature)
feature_MWT = pd.DataFrame(feature)
feature_MWT = feature_MWT.iloc[0:len(feature_MWT)-1]
feature_MWT
# Out:
#                                             0
# 0         audspec_lengthL1norm_sma_range_IC13
# 1        audspec_lengthL1norm_sma_maxPos_IC13
# 2        audspec_lengthL1norm_sma_minPos_IC13
# 3     audspec_lengthL1norm_sma_quartile1_IC13
# 4     audspec_lengthL1norm_sma_quartile2_IC13
# ...                                       ...
# 6363         mfcc_sma_de[14]_minRangeRel_IC13
# 6364     mfcc_sma_de[14]_meanRisingSlope_IC13
# 6365   mfcc_sma_de[14]_stddevRisingSlope_IC13
# 6366    mfcc_sma_de[14]_meanFallingSlope_IC13
# 6367  mfcc_sma_de[14]_stddevFallingSlope_IC13
#
# [6368 rows x 1 columns]

# %%
Man_Whi_P = pd.concat([feature_MWT , list_MWP], axis=1, join='inner')
Man_Whi_P
# Out:
#                                             0   statistic        pvalue
# 0         audspec_lengthL1norm_sma_range_IC13  41693794.0  3.496982e-02
# 1        audspec_lengthL1norm_sma_maxPos_IC13  41931322.5  7.521115e-03
# 2        audspec_lengthL1norm_sma_minPos_IC13  41908909.5  8.494348e-03
# 3     audspec_lengthL1norm_sma_quartile1_IC13  46341361.5  1.772744e-39
# 4     audspec_lengthL1norm_sma_quartile2_IC13  43481850.5  2.078985e-10
# ...                                       ...         ...           ...
# 6363         mfcc_sma_de[14]_minRangeRel_IC13  39587682.0  3.811417e-03
# 6364     mfcc_sma_de[14]_meanRisingSlope_IC13  44241712.0  3.348007e-16
# 6365   mfcc_sma_de[14]_stddevRisingSlope_IC13  41672192.0  3.964753e-02
# 6366    mfcc_sma_de[14]_meanFallingSlope_IC13  44253763.5  2.640554e-16
# 6367  mfcc_sma_de[14]_stddevFallingSlope_IC13  42136336.0  1.579009e-03
#
# [6368 rows x 3 columns]

# %%
Man_WHi_P_sorted = Man_Whi_P.sort_values('pvalue',ascending = True)
Man_WHi_P_sorted
# Out:
#                                              0   statistic        pvalue
# 5391                   mfcc_sma[11]_amean_IC13  32039820.5  2.867746e-96
# 5398             mfcc_sma[11]_peakMeanAbs_IC13  32263781.5  1.647383e-91
# 5233             mfcc_sma[4]_meanPeakDist_IC13  32430265.5  4.730585e-88
# 1832               mfcc_sma[11]_quartile1_IC13  32450264.0  1.217600e-87
# 1834               mfcc_sma[11]_quartile3_IC13  32603138.0  1.560713e-84
# ...                                        ...         ...           ...
# 4147    audspec_lengthL1norm_sma_qregerrQ_IC13  40808121.5  9.958414e-01
# 2320        audSpec_Rfilt_sma_de[11]_lpc0_IC13  40803759.5  9.958945e-01
# 5336       mfcc_sma[8]_stddevFallingSlope_IC13  40803841.5  9.960499e-01
# 3760        jitterLocal_sma_upleveltime25_IC13  40807360.5  9.972835e-01
# 950   audSpec_Rfilt_sma[22]_upleveltime50_IC13  40805189.5  9.986043e-01
#
# [6368 rows x 3 columns]

# %%
P_lesser_001 = Man_WHi_P_sorted.loc[(Man_WHi_P_sorted['pvalue']<0.001)]
P_lesser_001
#EXPORT FOR BOOTSTRAPPING P,.0001
P_lesser_0001 = Man_WHi_P_sorted.loc[(Man_WHi_P_sorted['pvalue']<0.0001)]
P_lesser_0001.to_csv("p0001_bootstrap")
# Out:
#                                         0   statistic        pvalue
# 5391              mfcc_sma[11]_amean_IC13  32039820.5  2.867746e-96
# 5398        mfcc_sma[11]_peakMeanAbs_IC13  32263781.5  1.647383e-91
# 5233        mfcc_sma[4]_meanPeakDist_IC13  32430265.5  4.730585e-88
# 1832          mfcc_sma[11]_quartile1_IC13  32450264.0  1.217600e-87
# 1834          mfcc_sma[11]_quartile3_IC13  32603138.0  1.560713e-84
# ...                                   ...         ...           ...
# 3887            F0final_sma_de_amean_IC13  39417728.0  9.772100e-04
# 5241     mfcc_sma[4]_meanRisingSlope_IC13  42193261.5  9.843697e-04
# 214        pcm_RMSenergy_sma_de_lpc2_IC13  42192403.0  9.915361e-04
# 4605    audSpec_Rfilt_sma[16]_qregc2_IC13  39419970.5  9.959044e-04
# 612   audSpec_Rfilt_sma[11]_risetime_IC13  39420248.5  9.982190e-04
#
# [3826 rows x 3 columns]

# %%
P_lesser_01 = Man_WHi_P_sorted.loc[(Man_WHi_P_sorted['pvalue']<0.01)&(Man_WHi_P_sorted['pvalue']>0.001)]
P_lesser_01
# Out:
#                                                       0   statistic    pvalue
# 5935         pcm_fftMag_fband250-650_sma_de_rqmean_IC13  39420885.5  0.001004
# 5805          audSpec_Rfilt_sma_de[17]_peakMeanAbs_IC13  39421251.0  0.001007
# 951            audSpec_Rfilt_sma[22]_upleveltime75_IC13  42190512.0  0.001007
# 593                audSpec_Rfilt_sma[11]_quartile2_IC13  42189799.5  0.001009
# 5966  pcm_fftMag_spectralRollOff25.0_sma_de_meanPeak...  39421978.0  0.001013
# ...                                                 ...         ...       ...
# 5159   pcm_fftMag_spectralHarmonicity_sma_qregerrQ_IC13  39716342.5  0.009659
# 2722               audSpec_Rfilt_sma_de[24]_lpgain_IC13  41893470.0  0.009796
# 6035  pcm_fftMag_spectralFlux_sma_de_stddevRisingSlo...  41893059.5  0.009824
# 5323                          mfcc_sma[8]_flatness_IC13  41892495.0  0.009862
# 2008             audSpec_Rfilt_sma_de[1]_leftctime_IC13  41891781.0  0.009910
#
# [488 rows x 3 columns]

# %%
P_lesser_05 = Man_WHi_P_sorted.loc[(Man_WHi_P_sorted['pvalue']<0.05)&(Man_WHi_P_sorted['pvalue']>0.01)]
P_lesser_05
# Out:
#                                                       0   statistic    pvalue
# 1559                     mfcc_sma[2]_percentile1.0_IC13  39721459.0  0.010006
# 4732        audSpec_Rfilt_sma[22]_peakMeanMeanDist_IC13  41889507.5  0.010067
# 120                               pcm_zcr_sma_lpc1_IC13  39723004.5  0.010112
# 3919                      F0final_sma_de_leftctime_IC13  39723626.0  0.010154
# 6353                      mfcc_sma_de[14]_flatness_IC13  39724066.0  0.010186
# ...                                                 ...         ...       ...
# 6125  pcm_fftMag_spectralSlope_sma_de_stddevRisingSl...  39978877.5  0.049500
# 4329                   audSpec_Rfilt_sma[4]_qregc2_IC13  39978934.0  0.049515
# 4712         audSpec_Rfilt_sma[21]_meanRisingSlope_IC13  41632614.0  0.049599
# 6197                    mfcc_sma_de[3]_peakMeanRel_IC13  41632139.5  0.049730
# 1531                            mfcc_sma[1]_stddev_IC13  39980019.0  0.049815
#
# [463 rows x 3 columns]

# %%
P_greater_05 = Man_WHi_P_sorted.loc[(Man_WHi_P_sorted['pvalue']>0.05)]
P_greater_05
# Out:
#                                                      0   statistic    pvalue
# 645                  audSpec_Rfilt_sma[12]_lpgain_IC13  41631124.0  0.050012
# 6122  pcm_fftMag_spectralSlope_sma_de_peakMeanRel_IC13  39980790.5  0.050029
# 292                 audSpec_Rfilt_sma[1]_skewness_IC13  39981070.0  0.050106
# 2168                 audSpec_Rfilt_sma_de[6]_lpc3_IC13  39981232.0  0.050151
# 2956  pcm_fftMag_spectralFlux_sma_de_pctlrange0-1_IC13  41630430.5  0.050204
# ...                                                ...         ...       ...
# 4147            audspec_lengthL1norm_sma_qregerrQ_IC13  40808121.5  0.995841
# 2320                audSpec_Rfilt_sma_de[11]_lpc0_IC13  40803759.5  0.995895
# 5336               mfcc_sma[8]_stddevFallingSlope_IC13  40803841.5  0.996050
# 3760                jitterLocal_sma_upleveltime25_IC13  40807360.5  0.997284
# 950           audSpec_Rfilt_sma[22]_upleveltime50_IC13  40805189.5  0.998604
#
# [1591 rows x 3 columns]
